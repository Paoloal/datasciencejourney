# %% [markdown]
# # Personal Finance Project Paolo Alberda

# %% [markdown]
# ### Importing the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading the csv file

# %%
df_ing_data = pd.read_csv('Alle_rekeningen_01-01-2015_13-08-2024.csv')
df_ing_data.head()
# Out:
#       Datum                Naam / Omschrijving            Rekening  \
# 0  20240810                     Apple Services  NL82INGB0001215409
# 1  20240810               Oranje Spaarrekening  NL82INGB0001215409
# 2  20240810                    Belastingdienst  NL82INGB0001215409
# 3  20240810               Oranje Spaarrekening  NL82INGB0001215409
# 4  20240809  D. Bindels via Rabo Betaalverzoek  NL82INGB0001215409
#
#         Tegenrekening Code Af Bij Bedrag (EUR)      Mutatiesoort  \
# 0  NL04ADYB2017400157   ID     Af        15,00             iDEAL
# 1                 NaN   GT    Bij        15,00  Online bankieren
# 2  NL86INGB0002445588   GT     Af       216,00  Online bankieren
# 3                 NaN   GT    Bij       216,00  Online bankieren
# 4  NL13RABO0181015595   ID     Af         9,09             iDEAL
#
#                                         Mededelingen
# 0  Naam: Apple Services Omschrijving: J84KBR5VLVH...
# 1  Van Oranje spaarrekening R34416091 Valutadatum...
# 2  Naam: Belastingdienst Omschrijving: 2240500312...
# 3  Van Oranje spaarrekening D34416090 Valutadatum...
# 4  Naam: D. Bindels via Rabo Betaalverzoek Omschr...

# %% [markdown]
# ### Change the column names to English

# %%
df_ing_data = df_ing_data.rename(columns={"Datum": "Date", "Naam / Omschrijving": "Description", "Rekening": "Account", "Tegenrekening":"Recipient",
                            "Code":"Code","Af Bij":"Added/Deducted","Bedrag (EUR)":"Amount EUR","Mutatiesoort":"Payment Type",
                            "Mededelingen":"Extra Description"})

# %%
df_ing_data
# Out:
#            Date                        Description             Account  \
# 0      20240810                     Apple Services  NL82INGB0001215409
# 1      20240810               Oranje Spaarrekening  NL82INGB0001215409
# 2      20240810                    Belastingdienst  NL82INGB0001215409
# 3      20240810               Oranje Spaarrekening  NL82INGB0001215409
# 4      20240809  D. Bindels via Rabo Betaalverzoek  NL82INGB0001215409
# ...         ...                                ...                 ...
# 12327  20230301                  Maja Nell Leutner  NL70INGB0100141463
# 12328  20230228                      Hr PF Alberda  NL70INGB0100141463
# 12329  20230228                Ista Nederland B.V.  NL70INGB0100141463
# 12330  20230228                      Hr PF Alberda  NL70INGB0100141463
# 12331  20230228                      Hr PF Alberda  NL70INGB0100141463
#
#                     Recipient Code Added/Deducted Amount EUR  \
# 0          NL04ADYB2017400157   ID             Af      15,00
# 1                         NaN   GT            Bij      15,00
# 2          NL86INGB0002445588   GT             Af     216,00
# 3                         NaN   GT            Bij     216,00
# 4          NL13RABO0181015595   ID             Af       9,09
# ...                       ...  ...            ...        ...
# 12327  DE67370696273009632017   OV            Bij     200,00
# 12328      NL82INGB0001215409   GT            Bij      60,00
# 12329      NL02INGB0675360641   GT             Af      60,00
# 12330      NL82INGB0001215409   GT            Bij      96,88
# 12331      NL82INGB0001215409   GT            Bij     103,12
#
#            Payment Type                                  Extra Description
# 0                 iDEAL  Naam: Apple Services Omschrijving: J84KBR5VLVH...
# 1      Online bankieren  Van Oranje spaarrekening R34416091 Valutadatum...
# 2      Online bankieren  Naam: Belastingdienst Omschrijving: 2240500312...
# 3      Online bankieren  Van Oranje spaarrekening D34416090 Valutadatum...
# 4                 iDEAL  Naam: D. Bindels via Rabo Betaalverzoek Omschr...
# ...                 ...                                                ...
# 12327    Overschrijving  Naam: Maja Nell Leutner Omschrijving: Grocerie...
# 12328  Online bankieren  Naam: Hr PF Alberda IBAN: NL82INGB0001215409 D...
# 12329  Online bankieren  Naam: Ista Nederland B.V. Omschrijving: Voorsc...
# 12330  Online bankieren  Naam: Hr PF Alberda Omschrijving: March Food I...
# 12331  Online bankieren  Naam: Hr PF Alberda Omschrijving: Leftovers gr...
#
# [12332 rows x 9 columns]

# %% [markdown]
# ### Format the date column

# %% [markdown]
# Option 1: I prefer this one because I want to treat it as a date column

# %%
# Step 1: Convert the Date column to a string format (if it's not already)
df_ing_data['Date'] = df_ing_data['Date'].astype(str)

# Step 2: Convert the string to a datetime object
df_ing_data['Date'] = pd.to_datetime(df_ing_data['Date'], format='%Y%m%d')

# Step 3: Format it back to a string in the desired format
df_ing_data['Date'] = df_ing_data['Date'].dt.strftime('%Y-%m-%d')

# %% [markdown]
# Option 2: If you do not treat it as a date function and you just want to modify a string and add hyphens

# %%
# Convert the 'Date' column to string if it's not already
df['Date'] = df['Date'].astype(str)
# Insert hyphens to format as 'YYYY-MM-DD'
df['Date'] = df['Date'].str[:4] + '-' + df['Date'].str[4:6] + '-' + df['Date'].str[6:]
# Display the DataFrame
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 # Convert the 'Date' column to string if it's not already
# ----> 2 df['Date'] = df['Date'].astype(str)
#       3 # Insert hyphens to format as 'YYYY-MM-DD'
#       4 df['Date'] = df['Date'].str[:4] + '-' + df['Date'].str[4:6] + '-' + df['Date'].str[6:]
#
# NameError: name 'df' is not defined

# %% [markdown]
# Option 3: Use a for loop

# %%
# Convert the 'Date' column to string if it's not already
df['Date'] = df['Date'].astype(str)

# Use a for loop to modify each date in the DataFrame
for i in range(len(df)):
    date_str = df.loc[i, 'Date']  # Access the string date
    formatted_date = date_str[:4] + '-' + date_str[4:6] + '-' + date_str[6:]  # Reformat it
    df.loc[i, 'Date'] = formatted_date  # Update the DataFrame with the new format

# Display the DataFrame
print(df)

# %%
df_ing_data
# Out:
#              Date                        Description             Account  \
# 0      2024-08-10                     Apple Services  NL82INGB0001215409
# 1      2024-08-10               Oranje Spaarrekening  NL82INGB0001215409
# 2      2024-08-10                    Belastingdienst  NL82INGB0001215409
# 3      2024-08-10               Oranje Spaarrekening  NL82INGB0001215409
# 4      2024-08-09  D. Bindels via Rabo Betaalverzoek  NL82INGB0001215409
# ...           ...                                ...                 ...
# 12327  2023-03-01                  Maja Nell Leutner  NL70INGB0100141463
# 12328  2023-02-28                      Hr PF Alberda  NL70INGB0100141463
# 12329  2023-02-28                Ista Nederland B.V.  NL70INGB0100141463
# 12330  2023-02-28                      Hr PF Alberda  NL70INGB0100141463
# 12331  2023-02-28                      Hr PF Alberda  NL70INGB0100141463
#
#                     Recipient Code Added/Deducted Amount EUR  \
# 0          NL04ADYB2017400157   ID             Af      15,00
# 1                         NaN   GT            Bij      15,00
# 2          NL86INGB0002445588   GT             Af     216,00
# 3                         NaN   GT            Bij     216,00
# 4          NL13RABO0181015595   ID             Af       9,09
# ...                       ...  ...            ...        ...
# 12327  DE67370696273009632017   OV            Bij     200,00
# 12328      NL82INGB0001215409   GT            Bij      60,00
# 12329      NL02INGB0675360641   GT             Af      60,00
# 12330      NL82INGB0001215409   GT            Bij      96,88
# 12331      NL82INGB0001215409   GT            Bij     103,12
#
#            Payment Type                                  Extra Description
# 0                 iDEAL  Naam: Apple Services Omschrijving: J84KBR5VLVH...
# 1      Online bankieren  Van Oranje spaarrekening R34416091 Valutadatum...
# 2      Online bankieren  Naam: Belastingdienst Omschrijving: 2240500312...
# 3      Online bankieren  Van Oranje spaarrekening D34416090 Valutadatum...
# 4                 iDEAL  Naam: D. Bindels via Rabo Betaalverzoek Omschr...
# ...                 ...                                                ...
# 12327    Overschrijving  Naam: Maja Nell Leutner Omschrijving: Grocerie...
# 12328  Online bankieren  Naam: Hr PF Alberda IBAN: NL82INGB0001215409 D...
# 12329  Online bankieren  Naam: Ista Nederland B.V. Omschrijving: Voorsc...
# 12330  Online bankieren  Naam: Hr PF Alberda Omschrijving: March Food I...
# 12331  Online bankieren  Naam: Hr PF Alberda Omschrijving: Leftovers gr...
#
# [12332 rows x 9 columns]

# %% [markdown]
# ### Remove unnecessary column(s)

# %%
df_ing_data.drop(columns=['Code'])
# Out:
#              Date                        Description             Account  \
# 0      2024-08-10                     Apple Services  NL82INGB0001215409
# 1      2024-08-10               Oranje Spaarrekening  NL82INGB0001215409
# 2      2024-08-10                    Belastingdienst  NL82INGB0001215409
# 3      2024-08-10               Oranje Spaarrekening  NL82INGB0001215409
# 4      2024-08-09  D. Bindels via Rabo Betaalverzoek  NL82INGB0001215409
# ...           ...                                ...                 ...
# 12327  2023-03-01                  Maja Nell Leutner  NL70INGB0100141463
# 12328  2023-02-28                      Hr PF Alberda  NL70INGB0100141463
# 12329  2023-02-28                Ista Nederland B.V.  NL70INGB0100141463
# 12330  2023-02-28                      Hr PF Alberda  NL70INGB0100141463
# 12331  2023-02-28                      Hr PF Alberda  NL70INGB0100141463
#
#                     Recipient Added/Deducted Amount EUR      Payment Type  \
# 0          NL04ADYB2017400157             Af      15,00             iDEAL
# 1                         NaN            Bij      15,00  Online bankieren
# 2          NL86INGB0002445588             Af     216,00  Online bankieren
# 3                         NaN            Bij     216,00  Online bankieren
# 4          NL13RABO0181015595             Af       9,09             iDEAL
# ...                       ...            ...        ...               ...
# 12327  DE67370696273009632017            Bij     200,00    Overschrijving
# 12328      NL82INGB0001215409            Bij      60,00  Online bankieren
# 12329      NL02INGB0675360641             Af      60,00  Online bankieren
# 12330      NL82INGB0001215409            Bij      96,88  Online bankieren
# 12331      NL82INGB0001215409            Bij     103,12  Online bankieren
#
#                                        Extra Description
# 0      Naam: Apple Services Omschrijving: J84KBR5VLVH...
# 1      Van Oranje spaarrekening R34416091 Valutadatum...
# 2      Naam: Belastingdienst Omschrijving: 2240500312...
# 3      Van Oranje spaarrekening D34416090 Valutadatum...
# 4      Naam: D. Bindels via Rabo Betaalverzoek Omschr...
# ...                                                  ...
# 12327  Naam: Maja Nell Leutner Omschrijving: Grocerie...
# 12328  Naam: Hr PF Alberda IBAN: NL82INGB0001215409 D...
# 12329  Naam: Ista Nederland B.V. Omschrijving: Voorsc...
# 12330  Naam: Hr PF Alberda Omschrijving: March Food I...
# 12331  Naam: Hr PF Alberda Omschrijving: Leftovers gr...
#
# [12332 rows x 8 columns]

# %% [markdown]
# ### Start adding Categories

# %% [markdown]
# Logic to fill the categories.
# 1. Add a categories columns
# 2. See which descriptions occur the most. This helps with filling the category columns
# 3. Create a database that includes all your transactions (descriptions) and assign a category to them based on the full description name.
# i.e. Albert Heijn Maastricht 1992 > Albert Heijn > Food Etc (Description, Company, Category) < structure of the database > for data labeling
# 4. Create predfined lists with keywords that can occur in the Description column. BASED on the database in step 3. If the keywords appear in Description column the it automatically inherit the category name from that list as a data label
# 5. Loop through with a for loop

# %%
# Add a categories column
df_ing_data["Category"] = ""

# %%
# Examine the most frequently occuring columns
freq_table_ing_description = pd.crosstab(df_ing_data['Description'], 'no_of_Description_Occurrences')   
freq_table_ing_description
freq_table_ing_description.sort_values(by=['no_of_Description_Occurrences'], ascending=False) 
freq_table_ing_description
# Out:
# col_0                                        no_of_Description_Occurrences
# Description
# 't Klaoske MAASTRICHT NLD                                                1
# 1144 action MAASTRICHT NLD                                               1
# 123test BV                                                               1
# 17649 Maastricht MAASTRICHT NLD                                          1
# 2525 Ventures B.V. via PAY.nl                                            1
# ...                                                                    ...
# ov-chipkaart/Trans Link Systems by Buckaroo                              4
# parkeerautomaat AZM MAASTRICHT                                           2
# slagerij Van Melik BP MAASTRICHT                                         1
# t Klaoske MAASTRICHT NLD                                                 1
# vans maastricht MAASTRICHT NLD                                           1
#
# [1569 rows x 1 columns]

# %%
# Investigate the "Hr PF Alberda" column in Description
df_ing_data_category_PF = df_ing_data.query("Description == 'Oranje Spaarrekening'")
df_ing_data_category_PF

# %%
# Create Predefined Lists by first changing the Description inputs to a list because im not going to type everything out myself
full_category_list = df_ing_data['Description'].tolist()
print(full_category_list)
# Out:
# ['Apple Services', 'Oranje Spaarrekening', 'Belastingdienst', 'Oranje Spaarrekening', 'D. Bindels via Rabo Betaalverzoek', 'Van Gool via Tikkie', 'Nationale-Nederlanden', 'Nationale-Nederlanden', 'INCASSO CREDITCARD ACCOUNTNR 210', 'Oranje Spaarrekening', 'Infomedics B.V.', 'Oranje Spaarrekening', 'Maja Nell Leutner', 'Mw MN Leutner', 'Stichting Woonpunt', 'OHRA Zorgverzekeringen', 'COOLBLUE BY BUCKAROO', 'BUDGET ENERGIE', 'Maja Nell Leutner', 'STORTING ING', 'Oranje Spaarrekening', 'Mw MN Leutner', 'Revolut**7005* Dublin IRL', 'Oranje Spaarrekening', 'Thuisbezorgd.nl ADFX7Z Utrecht', 'Mengelers Textiel MAASTRICHT NLD', 'KOFFIE BIJ JOOST EN MA NLD', 'Sportcity', 'Trans.Reference: F2C3054B77144F63', 'Oranje Spaarrekening', 'Ista Nederland B.V.', 'Oranje Spaarrekening', 'Mw MN Leutner', 'Coop Supermarkt 2274 MAASTRICHT', 'TECALLIANCE NETHERLANDS B.V.', 'Oranje Spaarrekening', 'Oranje Spaarrekening', 'Oranje Spaarrekening', 'TheWinners', 'Paolo Alberda', 'Flatex Bank AG', 'Flatex Bank AG', 'Alipay EUROPE LTD S.A', 'Coop Supermarkt 2274 MAASTRICHT', 'ALBERT HEIJN 1194 MAASTRICHT NLD', 'Oranje Spaarrekening', 'Oranje Spaarrekening', 'Oranje Spaarrekening', 'Coop Supermarkt 2274 MAASTRICHT', 'BSGW BELASTINGSAMENWERKING GEM EN WATERSCHAPPEN', 'Creditcard', 'Lebara BV', 'Zettle*A LA PACO MAASTRICHT NLD', 'HEMA EV016 MAASTRICH MAASTRICHT', 'PayPal Europe S.a.r.l. et Cie S.C.A', 'BELASTINGDIENST', 'Blokker391Maastricht MAASTRICHT', 'Fleurop-Interflora Nederland BV', 'Oranje Spaarrekening', 'Microsoft Payments', 'Oranje Spaarrekening', 'maassen via Tikkie', 'Oranje Spaarrekening', 'Mw M R J Suter', 'Alberda via Tikkie', 'Oranje Spaarrekening', 'Creditcard', 'Paolo Alberda', 'Mw MN Leutner', 'Creditcard', 'Apple Services', 'Kruidvat 4103 MAASTRICHT NLD', 'Hr PF Alberda,Mw MN Leutner', 'Mw MN Leutner', 'Revolut**7005* Dublin IRL', 'Hr PF Alberda,Mw MN Leutner', 'Nationale-Nederlanden', 'Nationale-Nederlanden', 'OHRA Zorgverzekeringen', 'COOLBLUE BY BUCKAROO', 'Stichting Woonpunt', 'TheWinners', 'Mw MN Leutner', 'Revolut**7005* Dublin IRL', 'Mw MN Leutner', 'Revolut**7005* Dublin IRL', 'Revolut**7005* Dublin IRL', 'Oranje Spaarrekening', 'NLOVKLJ4V9RAAVDJZY www.ovpay.nl', 'Oranje Spaarrekening', 'BUDGET ENERGIE', 'Oranje Spaarrekening', 'Sportcity', 'Icemart Reykjanesbaer ISL', 'HMS Host International Amsterdam', 'TheWinners', 'Oranje Spaarrekening', '3212 UT Kiosk sp 5 7 UTRECHT NLD', 'OHRA Schadeverzekeringen', 'Oranje Spaarrekening', 'Ista Nederland B.V.', 'Oranje Spaarrekening', 'Creditcard', 'Revolut**7005* Dublin IRL', 'Coop Supermarkt 2274 MAASTRICHT', 'BSGW BELASTINGSAMENWERKING GEM EN WATERSCHAPPEN', 'LEBARA', 'Oranje Spaarrekening', 'Creditcard', 'Creditcard', 'Oranje Spaarrekening', 'Oranje Spaarrekening', 'Flatex Bank AG', 'Flatex Bank AG', 'Flatex Bank AG', 'Paolo Alberda', 'Oranje Spaarrekening', 'TheWinners', 'Oranje Spaarrekening', 'TECALLIANCE NETHERLANDS B.V.', 'Vendingwork B.V. GRONINGEN NLD', 'Vendingwork B.V. GRONINGEN NLD', 'PayPal Europe S.a.r.l. et Cie S.C.A', 'CCV*Gelateria Luna Ros NLD', 'AH Kleijnen Ceramique MAASTRICHT', 'Zettle*A LA PACO MAASTRICHT NLD', 'TheWinners', 'Oranje Spaarrekening', 'HEMA EV016 MAASTRICH MAASTRICHT', 'Dunkin Utrecht NLD', 'SumUp  *DISORDER B.V Maastricht', 'Microsoft Payments', 'Oranje Spaarrekening', 'Oranje Spaarrekening', 'Stichting Woonpunt', 'Coop Supermarkt 2274 MAASTRICHT', 'Van Gool via Tikkie', 'D. Bindels via Rabo Betaalverzoek', 'Oranje Spaarrekening', 'ODIDO NETHERLANDS B.V.', 'BELASTINGDIENST', 'SuitSupply Amsterdam NLD', 'ALBERT HEIJN 1194 MAASTRICHT NLD', 'Oranje Spaarrekening', 'Hr PF Alberda,Mw MN Leutner', 'Oranje Spaarrekening', 'Mees Brightlands HOENSBROEK NLD', 'KOFFIE BIJ JOOST EN MA NLD', 'BCK*SoLow MAASTRICHT NLD', 'Albert Heijn 1194 MAASTRICHT NLD', 'AH Kleijnen Ceramique MAASTRICHT', 'Oranje Spaarrekening', 'ALBERT HEIJN 1194 MAASTRICHT NLD', 'Massimo Dutti 4771 MAASTRICHT', 'Zettle*A LA PACO MAASTRICHT NLD', 'Oranje Spaarrekening', 'Oranje Spaarrekening', 'Ora ...

# %%
create a for loop that checks the predefined list that is composed of the results in the freq_table_ing_description df
so
for i in description:
    if description is in list:
        fill category with list Name
    elif
    else:
